# %% [markdown]
# # ETF Data Check
#
# 本 notebook 只用于查看本地 ETF 数据缓存和质量报告，不生成投资建议、买卖信号或实盘交易代码。

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
data_path = project_root / 'data' / 'processed' / 'etf_daily_baostock.csv'
data_path

# %%
df = pd.read_csv(data_path, dtype={'code': str})
df.head()

# %%
df.groupby('code').agg(start_date=('date', 'min'), end_date=('date', 'max'), rows=('date', 'count')).head(20)

# %% [markdown]
# 质量报告位置：`reports/etf_data_quality_report.md`
